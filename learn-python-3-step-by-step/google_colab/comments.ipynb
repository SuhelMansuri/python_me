# %%
# This is a comment
# this is second comment
print('Hello World')

'''
This is a comment
This a block comment
a non standerd way of writing comments
'''
# Out:
# Hello World
# '\nThis is a comment\nThis a block comment\na non standerd way of writing comments\n'
