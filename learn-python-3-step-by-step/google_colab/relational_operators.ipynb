# %%
10>9
# Out:
# True

# %%
type(10>9)
# Out:
# bool

# %%
x = 10 > 9
print(x)
type(x)
# Out:
# True
# bool

# %%
10 < 9
# Out:
# False

# %%
10 >= 10
# Out:
# True

# %%
10 < 100
# Out:
# True

# %%
10 >= 9
# Out:
# True

# %%
9 <=9
# Out:
# True

# %%
10 == 10
# Out:
# True

# %%
10 == 9
# Out:
# False

# %%
10 != 9
# Out:
# True

# %%
10 != 10
# Out:
# False
