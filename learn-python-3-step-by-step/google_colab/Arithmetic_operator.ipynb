# %%
2 ** 3
# Out:
# 8

# %%
2 ** 3 ** 4
# Out:
# 2417851639229258349412352

# %%
2 * 3 * 4
# Out:
# 24

# %%
9/3
# Out:
# 3.0

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
type(10 // 3)
# Out:
# int

# %%
type(10 / 3)
# Out:
# float

# %%
10 / -3
# Out:
# -3.3333333333333335

# %%
10 // -3
# Out:
# -4

# %%
10 % 3
# Out:
# 1

# %%
10 % 5
# Out:
# 0

# %%
12 % 5
# Out:
# 2

# %%
12 + 5
# Out:
# 17

# %%
12 - 5
# Out:
# 7

# %%
3 * 6 + 7 - 2 / 4
# Out:
# 24.5

# %%
a,b,c = 10,20,30

# %%
x=12
y=5
z=x+y
p=x-y
q=z/p
r = x**y
s=x%y
print(x,' ',y,' ',z,' ',p,' ',q,' ',r,' ',s)
# Out:
# 12   5   17   7   2.4285714285714284   248832   2
