# %%
print('Hello', 'This is nice!!', 10, 3.5, sep = ' * ', end = ' $ ')
print('This is going to be in second line')
x = 10
type(x)
a = id(x)
print('id - x ', a)
y = 12
b = id(y)
print('id - y ', b)
y = 10
c = id(y)
print('id - y1 ', c)
x = x + 1
d = id(x)
print('id - x1 ', d)
print(x)
x = 4.5
type(x)
s1 = "Hello"
type(s1)
grade_point=9.5
age=15
print("Your age is",age,"and your grade point is",grade_point,end='.')
s1 = "This is Ela's Birthday!!"
print(s1)
len(s1)
s1= '   abcdef  '
len(s1)
s1 = s1.strip()
len(s1)
s1= '   abcdef  '
s1 = s1.lstrip()
len(s1)
s1 = s1.rstrip()
len(s1)
str1 = "12"
x=int(str1)
str2 = "5.75"
y=float(str2)
z = x + y
print(z)
# Out:
# Hello * This is nice!! * 10 * 3.5 $ This is going to be in second line
# id - x  140661227592272
# id - y  140661227592336
# id - y1  140661227592272
# id - x1  140661227592304
# 11
# Your age is 15 and your grade point is 9.5.This is Ela's Birthday!!
# 17.75

# %%
s1 = '1100'
x = int(s1, 2)
x
# Out:
# 8864

# %%
s1 = '1234'
x = int(s1, 2)
x
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-cca3e703cd50> in <module>
#       1 s1 = '1234'
# ----> 2 x = int(s1, 2)
#       3 x
#
# ValueError: invalid literal for int() with base 2: '1234'

# %%
s1 = '1a'
x = int(s1, 16)
x
# Out:
# 26
