# %%
s = input('Enter your name: ')
print(type(s))
print('Welcome, ', s)
str_age = input('Enter you age: ')
age = int(str_age)
print(type(str_age), type(age), s,' your are: ', age)
# Out:
# Enter your name: Suhel Mansuri
# <class 'str'>
# Welcome,  Suhel Mansuri
# Enter you age: 30
# <class 'str'> <class 'int'> Suhel Mansuri  Your are:  30
